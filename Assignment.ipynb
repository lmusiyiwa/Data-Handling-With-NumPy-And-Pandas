# %% [markdown]
# ASSIGNMENT 1
#
# WEATHER SENSOR DATA ANALYSIS

# %% [markdown]
# You are given temperature and humidity sensor readings for 3 cities over 4 days.
# The data is stored in a NumPy array of shape (3, 4, 2) where:
#
# axis 0 → City (0: Lagos, 1: Abuja, 2: Kano)
# axis 1 → Day (0: Day1, 1: Day2, 2: Day3, 3: Day4)
# axis 2 → Measurement (0: Temperature (°C), 1: Humidity (%))
# Tasks:
#
# 1. Print the shape, size, and dimensions of the weather_data.
# Verify what each axis represents.
#
# 2. Extract all temperature values for Lagos.
# Get the humidity values for Day 2 across all cities.
# Slice the data for Kano on Day 3.
#
# 3. Select temperatures for Lagos (Day 1), Abuja (Day 2), and Kano (Day 3) in one operation.
#
# 4. Find all days where the temperature > 30°C.
# Find all cities with humidity < 50%.
#
# 5. Create a new array by stacking only temperature data into shape (3,4). Do the same for humidity data.
#
# 6. Sort all temperature values (across all cities and days).
# Identify the day with the highest temperature in Abuja.
#
# 7. Compute the average temperature per city.
#
# 8. Compute the city with the overall lowest humidity.

# %%
ASSIGNMENT 2

PATIENT VITALS MONOTORING SYSTEM

# %% [markdown]
# You are a data scientist in a hospital. The hospital has collected vital signs data (Heart Rate, Systolic Blood Pressure, Diastolic Blood Pressure and Temperature) for 4 patients over a period of 3 days, measured twice per day (morning and evening).
#
# The data is stored in a NumPy array of shape (4, 3, 2, 4) where:
#
# Axis 0 → Patients (4 patients)
#
# Axis 1 → Days (3 days)
#
# Axis 2 → Time of Day (0 = Morning, 1 = Evening)
#
# Axis 3 → Vital Signs (0 = Heart Rate, 1 =  Systolic Blood Pressure, 2 = Diastolic Blood Pressure, 3 = Temperature)
#
# Your task is to use NumPy to perform the following:
#
# 1 - Generate synthetic data for the 4 patients.
#
# Heart Rate: 60–100 bpm
#
# Systolic Blood Pressure(SBP): 90–120 mmHg
#
# Diastolic Blood Pressure:60–80mmHg
#
# Temperature: 36–39 °C
#
#
# 2 - Extract all vital signs for Patient 0 on Day 3.
#
# 3 - Extract all Temperature values for Patient 3 across all days.
#
# 4 - Extract the Evening Heart Rate for all patients on Day 2.
#
#
# 5 - Extract the data for Patients 1, 2, and 4 only.
#
# 6 - Extract the data for Days 2, 3 for Patient 2.
#
# 7 - Find all readings where Temperature > 37.5°C.
#
# 8 - Identify patients who had Blood Pressure > 140 at any time.
#
# 9 - Compute the average Heart Rate per patient across all days.
#
# 10 - Find the maximum Temperature per day for Patient 3.
#
# 11 - Compute the overall mean SBP across all patients.
#
# 12 - Create a new array that stacks Heart Rate and Temperature only.
#
#
# 13 - Sort the average Heart Rate of all patients in ascending order.
